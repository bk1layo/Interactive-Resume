# %%
import pandas as pd

# %%
data = pd.read_csv("Life Expectancy Data.csv")

# %%
data
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %% [markdown]
# EDA (Exploary Data Analysis)

# %%
print("Number of rows =", len(data))
# Out:
# Number of rows = 2938

# %%
# find if there are null values
data.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# drop null values

data2 = data.dropna()

len(data2)
# Out:
# 1649

# %%
df_encoded = pd.get_dummies(data2, columns=['Status'])
# One-hot encode nominal variable 'Status'

# %%
df_encoded.to_csv("Life_Expectancy_preprocessed.csv")
# Save preprocessed csv files

# %%
df = pd.read_csv("Life_Expectancy_preprocessed.csv")
df = df.iloc[:, 1:]

df
# Out:
#           Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# 0     Afghanistan  2015              65.0            263.0             62
# 1     Afghanistan  2014              59.9            271.0             64
# 2     Afghanistan  2013              59.9            268.0             66
# 3     Afghanistan  2012              59.5            272.0             69
# 4     Afghanistan  2011              59.2            275.0             71
# ...           ...   ...               ...              ...            ...
# 1644     Zimbabwe  2004              44.3            723.0             27
# 1645     Zimbabwe  2003              44.5            715.0             26
# 1646     Zimbabwe  2002              44.8             73.0             25
# 1647     Zimbabwe  2001              45.3            686.0             25
# 1648     Zimbabwe  2000              46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  1649.000000       1649.000000      1649.000000    1649.000000
# mean   2007.840509         69.302304       168.215282      32.553062
# std       4.087711          8.796834       125.310417     120.847190
# min    2000.000000         44.000000         1.000000       0.000000
# 25%    2005.000000         64.400000        77.000000       1.000000
# 50%    2008.000000         71.700000       148.000000       3.000000
# 75%    2011.000000         75.000000       227.000000      22.000000
# max    2015.000000         89.000000       723.000000    1600.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  1649.000000             1649.000000  1649.000000    1649.000000
# mean      4.533196              698.973558    79.217708    2224.494239
# std       4.029189             1759.229336    25.604664   10085.802019
# ...

# %%
# corelation
import matplotlib.pyplot as plt
import seaborn as sns

colormap = plt.cm.PuBu
plt.figure(figsize=(12, 10))
plt.title("Pearson Correlation of Features", y = 1.05, size = 15)
sns.heatmap(df.iloc[:, 1:].corr(), linewidths = 0.1, vmax = 1.0,
           square = True, cmap = colormap, linecolor = "white", annot = True, annot_kws = {"size" : 8})
# Out:
# <Axes: title={'center': 'Pearson Correlation of Features'}>

# %%
correlation_matrix = df.iloc[:, 1:].corr()

# Extract values whose correlation exceeds threshold(ex: 0.5)
target_column = 'Life expectancy '
threshold = 0.4
columns_above_threshold = correlation_matrix.index[abs(correlation_matrix[target_column]) > threshold]

# print result
print("\nVariables whose correlation with the target variable exceeds {}:".format(threshold))
print(columns_above_threshold)
# Out:
# Variables whose correlation with the target variable exceeds 0.4:
# Index(['Life expectancy ', 'Adult Mortality', 'Alcohol',
#        'percentage expenditure', ' BMI ', ' HIV/AIDS', 'GDP',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'Status_Developed',
#        'Status_Developing'],
#       dtype='object')

# %% [markdown]
# Regression

# %%
columns_above_threshold = list(columns_above_threshold)
columns_above_threshold.remove('Life expectancy ')
# remove target value from list

# %%
X = df[columns_above_threshold]
y = df.iloc[:, -1]
y = y.values.reshape(-1, 1)
X.head()
# chosen variables only
# divide dataset into X(independent) and y(target)
# Out:
#    Adult Mortality  Alcohol  percentage expenditure   BMI    HIV/AIDS  \
# 0            263.0     0.01               71.279624   19.1        0.1
# 1            271.0     0.01               73.523582   18.6        0.1
# 2            268.0     0.01               73.219243   18.1        0.1
# 3            272.0     0.01               78.184215   17.6        0.1
# 4            275.0     0.01                7.097109   17.2        0.1
#
#           GDP   thinness  1-19 years   thinness 5-9 years  \
# 0  584.259210                   17.2                 17.3
# 1  612.696514                   17.5                 17.5
# 2  631.744976                   17.7                 17.7
# 3  669.959000                   17.9                 18.0
# 4   63.537231                   18.2                 18.2
#
#    Income composition of resources  Schooling  Status_Developed  \
# 0                            0.479       10.1             False
# ...

# %%
y
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error


# Save model performance for different ratios
train_ratios = np.arange(0.1, 1.0, 0.1)  # ratios (from 0.1 to 0.9, 0.1 interval)
r2_scores = []
rmse_list = []

for train_ratio in train_ratios:
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=train_ratio, random_state=42)
    
    # train model
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # evaluate model
    y_pred = model.predict(X_test)
    score = r2_score(y_test, y_pred)
    r2_scores.append(score)    # save score in the list
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse_list.append(rmse)     # save rmse in the list

# %%
# draw a graph
plt.figure(figsize=(10, 6))
plt.plot(train_ratios, r2_scores, marker='o', linestyle='-')
plt.title('Model Performance vs. Test Set Ratio')
plt.xlabel('Train Set Ratio')
plt.ylabel('R2 score')
plt.grid(True)
plt.show()

# %%
# graph
plt.figure(figsize=(10, 6))
plt.plot(train_ratios, rmse_list, marker='o', linestyle='-')
plt.title('Loss value vs. Train Set Ratio')
plt.xlabel('Train Set Ratio')
plt.ylabel('RMSE')
plt.grid(True)
plt.show()

# %% [markdown]
# The model performs best at a test set ratio of 0.4 to 0.6.
# I expected more than 0.9 but not as high as I expected.
# And when it comes to error, it grdually increases slightly.
#
# This is because underfitting occurs when there are few training sets, and overfitting occurs when there are too many training sets, making it difficult to predict test sets.
#
# Generally, the proportion of training sets is often 0.6 or 0.7, but in this case 0.5 looks best when comparing performance and error.
# What do you guys think?
